# %% [markdown]
# #### 1. Import the SQL database into Pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sqlalchemy import create_engine
from config import username
from config import password

# %%
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@localhost:5444/SQLhomework_SKG')
connection = engine.connect()

# %% [markdown]
# #### 2. Create a histogram to visualize the most common salary ranges for employees.

# %%
salary_df = pd.read_sql_query("SELECT * FROM salaries", connection)
salary_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
salary_df.sort_values(by=['salary'], inplace=True)
salary_df.head()
# Out:
#         emp_no  salary
# 281414  481390   40000
# 161252  261228   40000
# 221024  421000   40000
# 161253  261229   40000
# 161254  261230   40000

# %%
salary_df.columns
# Out:
# Index(['emp_no', 'salary'], dtype='object')

# %%
salary_only = salary_df.drop(['emp_no'], axis=1)

# %%
salary_only.hist(color='green')
plt.xlabel('salary range')
plt.ylabel('number of employees per salary range')
plt.savefig("salaries.png", mode="w")

# %% [markdown]
# #### 3. Create a bar chart of average salary by title.

# %%
# tables: employees, titles, salaries
# first
# rename emp_title_id to title_id in employees_df 
# then
# merge employees_df with titles_df on title_id to creat new df, emps_titles_df
# merge new df emps_titles_df with salaries_df on emp_no to create a new df, combined_df
# group by the titles 
# average the salaries
# drop the unnecessary columns

# %%
employees_df = pd.read_sql_query("SELECT * FROM employees", connection)
employees_df.rename(columns = {'emp_title_id':'title_id'}, inplace = True)
employees_df.head()
# Out:
#    emp_no title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302    s0001   7/25/1953    Hideyuki   Zallocco   M   4/28/1990
# 1  475053    e0002  11/18/1954       Byong  Delgrande   F    9/7/1991
# 2   57444    e0002   1/30/1958       Berry       Babb   F   3/21/1992
# 3  421786    s0001   9/28/1957       Xiong   Verhoeff   M  11/26/1987
# 4  282238    e0003  10/28/1952  Abdelkader    Baumann   F   1/18/1991

# %%
titles_df = pd.read_sql_query("SELECT * FROM titles", connection)
titles_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
emps_titles_df = pd.merge(left=employees_df, right=titles_df, left_on='title_id', right_on='title_id')
emps_titles_df
# Out:
#         emp_no title_id  birth_date  first_name   last_name sex   hire_date  \
# 0       473302    s0001   7/25/1953    Hideyuki    Zallocco   M   4/28/1990
# 1       421786    s0001   9/28/1957       Xiong    Verhoeff   M  11/26/1987
# 2       273487    s0001   4/14/1957   Christoph     Parfitt   M   6/28/1991
# 3       246449    s0001   3/23/1958       Subbu  Bultermann   F   3/25/1988
# 4        48085    s0001   1/19/1964  Venkatesan        Gilg   M   6/28/1993
# ...        ...      ...         ...         ...         ...  ..         ...
# 300019  111400    m0001   11/9/1959        Arie     Staelin   M    1/1/1985
# 300020  111133    m0001   3/16/1955       Hauke       Zhang   M  12/30/1986
# 300021  110085    m0001  10/28/1959        Ebru       Alpin   M    1/1/1985
# 300022  110386    m0001   10/4/1953        Shem      Kieras   M  10/14/1988
# 300023  111784    m0001   6/14/1956       Marjo  Giarratana   F   2/12/1988
#
#           title
# 0         Staff
# 1         Staff
# ...

# %%
combined_df = pd.merge(left=emps_titles_df, right=salary_df, left_on='emp_no', right_on='emp_no')
combined_df
# Out:
#         emp_no title_id  birth_date  first_name   last_name sex   hire_date  \
# 0       473302    s0001   7/25/1953    Hideyuki    Zallocco   M   4/28/1990
# 1       421786    s0001   9/28/1957       Xiong    Verhoeff   M  11/26/1987
# 2       273487    s0001   4/14/1957   Christoph     Parfitt   M   6/28/1991
# 3       246449    s0001   3/23/1958       Subbu  Bultermann   F   3/25/1988
# 4        48085    s0001   1/19/1964  Venkatesan        Gilg   M   6/28/1993
# ...        ...      ...         ...         ...         ...  ..         ...
# 300019  111400    m0001   11/9/1959        Arie     Staelin   M    1/1/1985
# 300020  111133    m0001   3/16/1955       Hauke       Zhang   M  12/30/1986
# 300021  110085    m0001  10/28/1959        Ebru       Alpin   M    1/1/1985
# 300022  110386    m0001   10/4/1953        Shem      Kieras   M  10/14/1988
# 300023  111784    m0001   6/14/1956       Marjo  Giarratana   F   2/12/1988
#
#           title  salary
# 0         Staff   40000
# ...

# %%
avg_salary_by_title = combined_df.groupby("title").mean()

# %%
avg_salary_by_title = avg_salary_by_title.drop(columns = 'emp_no', axis=1)
avg_salary_by_title
# Out:
#                           salary
# title
# Assistant Engineer  48564.434447
# Engineer            48535.336511
# Manager             51531.041667
# Senior Engineer     48506.799871
# Senior Staff        58550.172704
# Staff               58465.382850
# Technique Leader    48582.896092

# %%
avg_salary_by_title.plot(kind='bar', y='salary', color='green',)
plt.grid()
plt.savefig("avgsalarybytitle.png", mode="w")
